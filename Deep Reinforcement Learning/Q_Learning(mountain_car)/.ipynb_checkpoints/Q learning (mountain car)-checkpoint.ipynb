# %% [markdown]
# # Q Learning Generalization
#
# - In continuous space, the Q learining algorithm based on grid world state that we implemented in the cart-pole is not good enough due to the curse of dimensionality.
#
# - Example of generalization: when people drive, they do not necessarily remember each distintive state. Instead, they based on their observation, generalizing the state based on that and make a decision (look at the scene in front and drive)
#
# - Based on https://github.com/lazyprogrammer/
#
# - Pseudocode (from Berkeley Deep Reinforcement Learning course)
#
# <img src="Q_Learning.png">

# %%
import gym
import numpy as np

## Visualization purpose
import helper
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from matplotlib import pyplot as plt
from IPython.display import display

# %matplotlib inline

# %%
env = gym.make('MountainCar-v0')
# Out:
# [2017-10-10 23:07:03,593] Making new env: MountainCar-v0

# %%
observation = env.reset()
cum_reward = 0
frames = []
for t in range(5000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    #print 'Observation: ', observation
    if done:
        print 'Number of step: ', t
        break
env.render(close=True)
helper.display_frames_as_gif(frames)  #<<< This one for Jupyter Notebook Display
# Out:
# Number of step:  199
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgAIHTSQJMUHPFXBFF">
#     <br>
#     <input id="_anim_sliderAIHTSQJMUHPFXBFF" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animAIHTSQJMUHPFXBFF.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animAIHTSQJMUHPFXBFF.slower()">&#8211;</button>
#     <button onclick="animAIHTSQJMUHPFXBFF.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animAIHTSQJMUHPFXBFF.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animAIHTSQJMUHPFXBFF.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animAIHTSQJMUHPFXBFF.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animAIHTSQJMUHPFXBFF.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animAIHTSQJMUHPFXBFF.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animAIHTSQJMUHPFXBFF.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animAIHTSQJMUHPFXBFF.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectAIHTSQJMUHPFXBFF" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgAIHTSQJMUHPFXBFF";
#     var slider_id = "_anim_sliderAIHTSQJMUHPFXBFF";
#     var loop_select_id = "_anim_loop_selectAIHTSQJMUHPFXBFF";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
state = env.observation_space
print 'Number of states:', state
print 'Number of available actions: ',env.action_space
# Out:
# Number of states: Box(2,)
# Number of available actions:  Discrete(3)

# %% [markdown]
# ** In previous project, we understand and figure our the effect of actions to the system. In fact, in term of reinforcement learning, We do not need to know them anymore**

# %% [markdown]
# RBF Model for Q learning algorithm:

# %%
env.action_space.n
# Out:
# 3

# %%
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDRegressor

# %% [markdown]
# Feature transformer based on RBF kernel

# %%
observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
#observation_examples = observation_examples.reshape(1,-1)
scaler = StandardScaler()
scaler.fit(observation_examples)

featurizer = FeatureUnion([
            ("rbf1", RBFSampler(gamma=5.0, n_components=500)),
            ("rbf2", RBFSampler(gamma=2.0, n_components=500)),
            ("rbf3", RBFSampler(gamma=1.0, n_components=500)),
            ("rbf4", RBFSampler(gamma=0.5, n_components=500))
            ])
featurizer.fit(scaler.transform(observation_examples))
def FeatureTransform(feature):
    #feature = feature.reshape(1,-1)
    #example_features = featurizer.fit_transform(scaler.transform(observation_examples))
    return featurizer.transform(scaler.transform(feature))
    #return scaler.transform(feature)

# %%
#Since we have 3 actions available, we can have 3 models
#learning_rate = 'constant'
gamma = 0.99
models = []
for i in range(env.action_space.n):
    model = SGDRegressor(learning_rate='constant')
    model.partial_fit(FeatureTransform([env.reset()]), [0])
    models.append(model)

# %%
for i in range(3):
    print len(models[i].coef_)
# Out:
# 2000
# 2000
# 2000

# %%
def predict(state):
    transformed_feature = FeatureTransform([state])
    return np.array([models[i].predict(transformed_feature)[0] for i in range(3)])

# %%
predict(env.reset())
# Out:
# array([ 0.,  0.,  0.])

# %%
def next_action(state, eps):
    if np.random.random() < eps:
        return env.action_space.sample()
    else:
        return np.argmax(predict(state))

# %%
gamma = 0.99
for i in range (300): # We play 1000 episodes
    done = False
    s = env.reset()
    time = 0 #keep track how long
    total_reward = 0
    eps = (0.97**i)
    while not done:
        action = next_action(s, eps) # Whatever it can be, because Q learning is an off-policy learning algorithms
        s_landed, reward, done,info = env.step(action)
        time = time + 1
        #Q =  gamma*max_action(s_landed)
        Q = gamma*np.max(predict(s_landed)[0])
        G = reward + Q
        models[action].partial_fit(FeatureTransform([s]), [G])
        s = s_landed
        total_reward += reward
    print 'Finish episode #', i, 'time is: ', time, 'reward is: ', total_reward
# Out:
# Finish episode # 0 time is:  200 reward is:  -200.0
# Finish episode # 1 time is:  200 reward is:  -200.0
# Finish episode # 2 time is:  200 reward is:  -200.0
# Finish episode # 3 time is:  200 reward is:  -200.0
# Finish episode # 4 time is:  200 reward is:  -200.0
# Finish episode # 5 time is:  200 reward is:  -200.0
# Finish episode # 6 time is:  200 reward is:  -200.0
# Finish episode # 7 time is:  200 reward is:  -200.0
# Finish episode # 8 time is:  200 reward is:  -200.0
# Finish episode # 9 time is:  200 reward is:  -200.0
# Finish episode # 10 time is:  200 reward is:  -200.0
# Finish episode # 11 time is:  200 reward is:  -200.0
# Finish episode # 12 time is:  200 reward is:  -200.0
# Finish episode # 13 time is:  200 reward is:  -200.0
# Finish episode # 14 time is:  200 reward is:  -200.0
# Finish episode # 15 time is:  200 reward is:  -200.0
# Finish episode # 16 time is:  200 reward is:  -200.0
# Finish episode # 17 time is:  200 reward is:  -200.0
# Finish episode # 18 time is:  200 reward is:  -200.0
# Finish episode # 19 time is:  200 reward is:  -200.0
# Finish episode # 20 time is:  200 reward is:  -200.0
# Finish episode # 21 time is:  200 reward is:  -200.0
# Finish episode # 22 time is:  200 reward is:  -200.0
# Finish episode # 23 time is:  200 reward is:  -200.0
# Finish episode # 24 time is:  200 reward is:  -200.0
# Finish episode # 25 time is:  200 reward is:  -200.0
# Finish episode # 26 time is:  200 reward is:  -200.0
# Finish episode # 27 time is:  200 reward is:  -200.0
# Finish episode # 28 time is:  200 reward is:  -200.0
# Finish episode # 29 time is:  180 reward is:  -180.0
# Finish episode # 30 time is:  200 reward is:  -200.0
# Finish episode # 31 time is:  169 reward is:  -169.0
# Finish episode # 32 time is:  195 reward is:  -195.0
# Finish episode # 33 time is:  200 reward is:  -200.0
# Finish episode # 34 time is:  200 reward is:  -200.0
# Finish episode # 35 time is:  167 reward is:  -167.0
# Finish episode # 36 time is:  200 reward is:  -200.0
# Finish episode # 37 time is:  171 reward is:  -171.0
# Finish episode # 38 time is:  166 reward is:  -166.0
# Finish episode # 39 time is:  200 reward is:  -200.0
# Finish episode # 40 time is:  200 reward is:  -200.0
# Finish episode # 41 time is:  200 reward is:  -200.0
# Finish episode # 42 time is:  171 reward is:  -171.0
# Finish episode # 43 time is:  200 reward is:  -200.0
# Finish episode # 44 time is:  200 reward is:  -200.0
# Finish episode # 45 time is:  200 reward is:  -200.0
# Finish episode # 46 time is:  200 reward is:  -200.0
# Finish episode # 47 time is:  158 reward is:  -158.0
# Finish episode # 48 time is:  164 reward is:  -164.0
# Finish episode # 49 time is:  170 reward is:  -170.0
# Finish episode # 50 time is:  200 reward is:  -200.0
# Finish episode # 51 time is:  135 reward is:  -135.0
# Finish episode # 52 time is:  161 reward is:  -161.0
# Finish episode # 53 time is:  158 reward is:  -158.0
# Finish episode # 54 time is:  150 reward is:  -150.0
# Finish episode # 55 time is:  154 reward is:  -154.0
# Finish episode # 56 time is:  143 reward is:  -143.0
# Finish episode # 57 time is:  151 reward is:  -151.0
# Finish episode # 58 time is:  155 reward is:  -155.0
# Finish episode # 59 time is:  155 reward is:  -155.0
# Finish episode # 60 time is:  159 reward is:  -159.0
# Finish episode # 61 time is:  160 reward is:  -160.0
# Finish episode # 62 time is:  152 reward is:  -152.0
# Finish episode # 63 time is:  151 reward is:  -151.0
# Finish episode # 64 time is:  159 reward is:  -159.0
# Finish episode # 65 time is:  146 reward is:  -146.0
# Finish episode # 66 time is:  154 reward is:  -154.0
# Finish episode # 67 time is:  159 reward is:  -159.0
# Finish episode # 68 time is:  151 reward is:  -151.0
# Finish episode # 69 time is:  154 reward is:  -154.0
# Finish episode # 70 time is:  164 reward is:  -164.0
# Finish episode # 71 time is:  162 reward is:  -162.0
# Finish episode # 72 time is:  158 reward is:  -158.0
# Finish episode # 73 time is:  161 reward is:  -161.0
# Finish episode # 74 time is:  200 reward is:  -200.0
# Finish episode # 75 time is:  146 reward is:  -146.0
# Finish episode # 76 time is:  156 reward is:  -156.0
# Finish episode # 77 time is:  173 reward is:  -173.0
# Finish episode # 78 time is:  152 reward is:  -152.0
# Finish episode # 79 time is:  155 reward is:  -155.0
# Finish episode # 80 time is:  159 reward is:  -159.0
# Finish episode # 81 time is:  158 reward is:  -158.0
# Finish episode # 82 time is:  152 reward is:  -152.0
# Finish episode # 83 time is:  142 reward is:  -142.0
# Finish episode # 84 time is:  142 reward is:  -142.0
# Finish episode # 85 time is:  145 reward is:  -145.0
# Finish episode # 86 time is:  156 reward is:  -156.0
# Finish episode # 87 time is:  152 reward is:  -152.0
# Finish episode # 88 time is:  145 reward is:  -145.0
# Finish episode # 89 time is:  152 reward is:  -152.0
# Finish episode # 90 time is:  164 reward is:  -164.0
# Finish episode # 91 time is:  149 reward is:  -149.0
# Finish episode # 92 time is:  153 reward is:  -153.0
# Finish episode # 93 time is:  154 reward is:  -154.0
# Finish episode # 94 time is:  153 reward is:  -153.0
# Finish episode # 95 time is:  154 reward is:  -154.0
# Finish episode # 96 time is:  144 reward is:  -144.0
# Finish episode # 97 time is:  148 reward is:  -148.0
# Finish episode # 98 time is:  149 reward is:  -149.0
# Finish episode # 99 time is:  151 reward is:  -151.0
# Finish episode # 100 time is:  150 reward is:  -150.0
# Finish episode # 101 time is:  151 reward is:  -151.0
# Finish episode # 102 time is:  150 reward is:  -150.0
# Finish episode # 103 time is:  145 reward is:  -145.0
# Finish episode # 104 time is:  164 reward is:  -164.0
# Finish episode # 105 time is:  153 reward is:  -153.0
# Finish episode # 106 time is:  159 reward is:  -159.0
# Finish episode # 107 time is:  156 reward is:  -156.0
# Finish episode # 108 time is:  149 reward is:  -149.0
# Finish episode # 109 time is:  152 reward is:  -152.0
# Finish episode # 110 time is:  154 reward is:  -154.0
# Finish episode # 111 time is:  165 reward is:  -165.0
# Finish episode # 112 time is:  157 reward is:  -157.0
# Finish episode # 113 time is:  152 reward is:  -152.0
# Finish episode # 114 time is:  146 reward is:  -146.0
# Finish episode # 115 time is:  150 reward is:  -150.0
# Finish episode # 116 time is:  148 reward is:  -148.0
# Finish episode # 117 time is:  154 reward is:  -154.0
# Finish episode # 118 time is:  158 reward is:  -158.0
# Finish episode # 119 time is:  154 reward is:  -154.0
# Finish episode # 120 time is:  157 reward is:  -157.0
# Finish episode # 121 time is:  150 reward is:  -150.0
# Finish episode # 122 time is:  148 reward is:  -148.0
# Finish episode # 123 time is:  164 reward is:  -164.0
# Finish episode # 124 time is:  146 reward is:  -146.0
# Finish episode # 125 time is:  147 reward is:  -147.0
# Finish episode # 126 time is:  153 reward is:  -153.0
# Finish episode # 127 time is:  155 reward is:  -155.0
# Finish episode # 128 time is:  148 reward is:  -148.0
# Finish episode # 129 time is:  155 reward is:  -155.0
# Finish episode # 130 time is:  151 reward is:  -151.0
# Finish episode # 131 time is:  154 reward is:  -154.0
# Finish episode # 132 time is:  143 reward is:  -143.0
# Finish episode # 133 time is:  143 reward is:  -143.0
# Finish episode # 134 time is:  145 reward is:  -145.0
# Finish episode # 135 time is:  146 reward is:  -146.0
# Finish episode # 136 time is:  144 reward is:  -144.0
# Finish episode # 137 time is:  162 reward is:  -162.0
# Finish episode # 138 time is:  140 reward is:  -140.0
# Finish episode # 139 time is:  141 reward is:  -141.0
# Finish episode # 140 time is:  149 reward is:  -149.0
# Finish episode # 141 time is:  142 reward is:  -142.0
# Finish episode # 142 time is:  154 reward is:  -154.0
# Finish episode # 143 time is:  139 reward is:  -139.0
# Finish episode # 144 time is:  147 reward is:  -147.0
# Finish episode # 145 time is:  146 reward is:  -146.0
# Finish episode # 146 time is:  148 reward is:  -148.0
# Finish episode # 147 time is:  144 reward is:  -144.0
# Finish episode # 148 time is:  147 reward is:  -147.0
# Finish episode # 149 time is:  164 reward is:  -164.0
# Finish episode # 150 time is:  85 reward is:  -85.0
# Finish episode # 151 time is:  149 reward is:  -149.0
# Finish episode # 152 time is:  147 reward is:  -147.0
# Finish episode # 153 time is:  155 reward is:  -155.0
# Finish episode # 154 time is:  152 reward is:  -152.0
# Finish episode # 155 time is:  160 reward is:  -160.0
# Finish episode # 156 time is:  142 reward is:  -142.0
# Finish episode # 157 time is:  145 reward is:  -145.0
# Finish episode # 158 time is:  147 reward is:  -147.0
# Finish episode # 159 time is:  141 reward is:  -141.0
# Finish episode # 160 time is:  148 reward is:  -148.0
# Finish episode # 161 time is:  148 reward is:  -148.0
# Finish episode # 162 time is:  153 reward is:  -153.0
# Finish episode # 163 time is:  164 reward is:  -164.0
# Finish episode # 164 time is:  169 reward is:  -169.0
# Finish episode # 165 time is:  146 reward is:  -146.0
# Finish episode # 166 time is:  150 reward is:  -150.0
# Finish episode # 167 time is:  149 reward is:  -149.0
# Finish episode # 168 time is:  147 reward is:  -147.0
# Finish episode # 169 time is:  148 reward is:  -148.0
# Finish episode # 170 time is:  149 reward is:  -149.0
# Finish episode # 171 time is:  143 reward is:  -143.0
# Finish episode # 172 time is:  144 reward is:  -144.0
# Finish episode # 173 time is:  146 reward is:  -146.0
# Finish episode # 174 time is:  141 reward is:  -141.0
# Finish episode # 175 time is:  161 reward is:  -161.0
# Finish episode # 176 time is:  139 reward is:  -139.0
# Finish episode # 177 time is:  148 reward is:  -148.0
# Finish episode # 178 time is:  151 reward is:  -151.0
# Finish episode # 179 time is:  162 reward is:  -162.0
# Finish episode # 180 time is:  143 reward is:  -143.0
# Finish episode # 181 time is:  150 reward is:  -150.0
# Finish episode # 182 time is:  161 reward is:  -161.0
# Finish episode # 183 time is:  147 reward is:  -147.0
# Finish episode # 184 time is:  146 reward is:  -146.0
# Finish episode # 185 time is:  149 reward is:  -149.0
# Finish episode # 186 time is:  147 reward is:  -147.0
# Finish episode # 187 time is:  145 reward is:  -145.0
# Finish episode # 188 time is:  87 reward is:  -87.0
# Finish episode # 189 time is:  86 reward is:  -86.0
# Finish episode # 190 time is:  141 reward is:  -141.0
# Finish episode # 191 time is:  157 reward is:  -157.0
# Finish episode # 192 time is:  144 reward is:  -144.0
# Finish episode # 193 time is:  144 reward is:  -144.0
# Finish episode # 194 time is:  141 reward is:  -141.0
# Finish episode # 195 time is:  163 reward is:  -163.0
# Finish episode # 196 time is:  145 reward is:  -145.0
# Finish episode # 197 time is:  155 reward is:  -155.0
# Finish episode # 198 time is:  148 reward is:  -148.0
# Finish episode # 199 time is:  156 reward is:  -156.0
# Finish episode # 200 time is:  150 reward is:  -150.0
# Finish episode # 201 time is:  145 reward is:  -145.0
# Finish episode # 202 time is:  165 reward is:  -165.0
# Finish episode # 203 time is:  154 reward is:  -154.0
# Finish episode # 204 time is:  88 reward is:  -88.0
# Finish episode # 205 time is:  85 reward is:  -85.0
# Finish episode # 206 time is:  150 reward is:  -150.0
# Finish episode # 207 time is:  85 reward is:  -85.0
# Finish episode # 208 time is:  169 reward is:  -169.0
# Finish episode # 209 time is:  150 reward is:  -150.0
# Finish episode # 210 time is:  149 reward is:  -149.0
# Finish episode # 211 time is:  162 reward is:  -162.0
# Finish episode # 212 time is:  85 reward is:  -85.0
# Finish episode # 213 time is:  93 reward is:  -93.0
# Finish episode # 214 time is:  161 reward is:  -161.0
# Finish episode # 215 time is:  153 reward is:  -153.0
# Finish episode # 216 time is:  163 reward is:  -163.0
# Finish episode # 217 time is:  86 reward is:  -86.0
# Finish episode # 218 time is:  146 reward is:  -146.0
# Finish episode # 219 time is:  150 reward is:  -150.0
# Finish episode # 220 time is:  156 reward is:  -156.0
# Finish episode # 221 time is:  151 reward is:  -151.0
# Finish episode # 222 time is:  85 reward is:  -85.0
# Finish episode # 223 time is:  151 reward is:  -151.0
# Finish episode # 224 time is:  159 reward is:  -159.0
# Finish episode # 225 time is:  88 reward is:  -88.0
# Finish episode # 226 time is:  157 reward is:  -157.0
# Finish episode # 227 time is:  149 reward is:  -149.0
# Finish episode # 228 time is:  92 reward is:  -92.0
# Finish episode # 229 time is:  149 reward is:  -149.0
# Finish episode # 230 time is:  154 reward is:  -154.0
# Finish episode # 231 time is:  86 reward is:  -86.0
# Finish episode # 232 time is:  94 reward is:  -94.0
# Finish episode # 233 time is:  148 reward is:  -148.0
# Finish episode # 234 time is:  96 reward is:  -96.0
# Finish episode # 235 time is:  88 reward is:  -88.0
# Finish episode # 236 time is:  164 reward is:  -164.0
# Finish episode # 237 time is:  158 reward is:  -158.0
# Finish episode # 238 time is:  155 reward is:  -155.0
# Finish episode # 239 time is:  158 reward is:  -158.0
# Finish episode # 240 time is:  164 reward is:  -164.0
# Finish episode # 241 time is:  91 reward is:  -91.0
# Finish episode # 242 time is:  94 reward is:  -94.0
# Finish episode # 243 time is:  200 reward is:  -200.0
# Finish episode # 244 time is:  85 reward is:  -85.0
# Finish episode # 245 time is:  152 reward is:  -152.0
# Finish episode # 246 time is:  98 reward is:  -98.0
# Finish episode # 247 time is:  88 reward is:  -88.0
# Finish episode # 248 time is:  148 reward is:  -148.0
# Finish episode # 249 time is:  157 reward is:  -157.0
# Finish episode # 250 time is:  155 reward is:  -155.0
# Finish episode # 251 time is:  154 reward is:  -154.0
# Finish episode # 252 time is:  159 reward is:  -159.0
# Finish episode # 253 time is:  94 reward is:  -94.0
# Finish episode # 254 time is:  96 reward is:  -96.0
# Finish episode # 255 time is:  91 reward is:  -91.0
# Finish episode # 256 time is:  97 reward is:  -97.0
# Finish episode # 257 time is:  90 reward is:  -90.0
# Finish episode # 258 time is:  149 reward is:  -149.0
# Finish episode # 259 time is:  87 reward is:  -87.0
# Finish episode # 260 time is:  97 reward is:  -97.0
# Finish episode # 261 time is:  92 reward is:  -92.0
# Finish episode # 262 time is:  88 reward is:  -88.0
# Finish episode # 263 time is:  200 reward is:  -200.0
# Finish episode # 264 time is:  157 reward is:  -157.0
# Finish episode # 265 time is:  149 reward is:  -149.0
# Finish episode # 266 time is:  153 reward is:  -153.0
# Finish episode # 267 time is:  153 reward is:  -153.0
# Finish episode # 268 time is:  152 reward is:  -152.0
# Finish episode # 269 time is:  152 reward is:  -152.0
# Finish episode # 270 time is:  88 reward is:  -88.0
# Finish episode # 271 time is:  152 reward is:  -152.0
# Finish episode # 272 time is:  154 reward is:  -154.0
# Finish episode # 273 time is:  156 reward is:  -156.0
# Finish episode # 274 time is:  172 reward is:  -172.0
# Finish episode # 275 time is:  155 reward is:  -155.0
# Finish episode # 276 time is:  150 reward is:  -150.0
# Finish episode # 277 time is:  154 reward is:  -154.0
# Finish episode # 278 time is:  150 reward is:  -150.0
# Finish episode # 279 time is:  159 reward is:  -159.0
# Finish episode # 280 time is:  156 reward is:  -156.0
# Finish episode # 281 time is:  153 reward is:  -153.0
# Finish episode # 282 time is:  178 reward is:  -178.0
# Finish episode # 283 time is:  95 reward is:  -95.0
# Finish episode # 284 time is:  153 reward is:  -153.0
# Finish episode # 285 time is:  89 reward is:  -89.0
# Finish episode # 286 time is:  95 reward is:  -95.0
# Finish episode # 287 time is:  200 reward is:  -200.0
# Finish episode # 288 time is:  97 reward is:  -97.0
# Finish episode # 289 time is:  155 reward is:  -155.0
# Finish episode # 290 time is:  155 reward is:  -155.0
# Finish episode # 291 time is:  103 reward is:  -103.0
# Finish episode # 292 time is:  200 reward is:  -200.0
# Finish episode # 293 time is:  92 reward is:  -92.0
# Finish episode # 294 time is:  151 reward is:  -151.0
# Finish episode # 295 time is:  88 reward is:  -88.0
# Finish episode # 296 time is:  156 reward is:  -156.0
# Finish episode # 297 time is:  152 reward is:  -152.0
# Finish episode # 298 time is:  86 reward is:  -86.0
# Finish episode # 299 time is:  159 reward is:  -159.0

# %%
observation = env.reset()
cum_reward = 0
frames = []
for t in range(5000):
    # Render into buffer. 
    frames.append(env.render(mode = 'rgb_array'))
    action = np.argmax(predict(observation))
    observation, reward, done, info = env.step(action)
    #print 'Observation: ', observation
    if done:
        print 'Number of step: ', t
        break
env.render(close=True)
helper.display_frames_as_gif(frames)  #<<< This one for Jupyter Notebook Display
# Out:
# Number of step:  100
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgRFWLLEDDXDVJXWGH">
#     <br>
#     <input id="_anim_sliderRFWLLEDDXDVJXWGH" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animRFWLLEDDXDVJXWGH.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animRFWLLEDDXDVJXWGH.slower()">&#8211;</button>
#     <button onclick="animRFWLLEDDXDVJXWGH.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRFWLLEDDXDVJXWGH.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRFWLLEDDXDVJXWGH.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRFWLLEDDXDVJXWGH.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animRFWLLEDDXDVJXWGH.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRFWLLEDDXDVJXWGH.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRFWLLEDDXDVJXWGH.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRFWLLEDDXDVJXWGH.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectRFWLLEDDXDVJXWGH" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgRFWLLEDDXDVJXWGH";
#     var slider_id = "_anim_sliderRFWLLEDDXDVJXWGH";
#     var loop_select_id = "_anim_loop_selectRFWLLEDDXDVJXWGH";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
